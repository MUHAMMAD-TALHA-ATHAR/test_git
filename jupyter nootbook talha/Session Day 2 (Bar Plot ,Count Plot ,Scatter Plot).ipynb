# %%
# Body mass index(BMI)
# input weight
# Height
# BMI (Ask your your height)
# weight
# calculate BMI   (weight in kg / height in meter and its square)
# print BMI(My name is ______ , my BMI is ______)

# %%
name = input("Enter your name: ")
height = float(input("Enter your height in meter: "))
weight = float(input("Enter your weight in kg: "))
bmi = weight/(height)**2
print(f"My name is {name}, and my BMI is {bmi}")
# Out:
# Enter your name: Ali
# Enter your height in meter: 1.676
# Enter your weight in kg: 50
# My name is Ali, and my BMI is 17.800080883567535

# %% [markdown]
# ---

# %% [markdown]
# # Bar Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)

titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Count Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
p1=sns.countplot(x="sex", data=titanic, hue="class")
p1.set_title("plot for Counting")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row="sex", hue="alone")
g=(g.map(plt.scatter, "age", "fare").add_legend())
plt.show()
